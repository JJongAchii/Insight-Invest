# %%
import yfinance as yf


data = yf.download('SPY', start='2025-11-01', end='2025-11-30')


data
# Out:
# Failed to get ticker 'SPY' reason: Expecting value: line 1 column 1 (char 0)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Empty DataFrame
# Columns: [(Adj Close, SPY), (Close, SPY), (High, SPY), (Low, SPY), (Open, SPY), (Volume, SPY)]
# Index: []

# %%
import yfinance as yf
from curl_cffi import requests

session = requests.Session(impersonate="chrome")
ticker = yf.Ticker('SPY')

data = ticker.history(
    start='2025-11-15',
    end='2025-11-23',
)

data
# Out:
# Failed to get ticker 'SPY' reason: Expecting value: line 1 column 1 (char 0)
# $SPY: possibly delisted; no timezone found
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
# Alternative: Try using period instead of start/end dates
import yfinance as yf

ticker = yf.Ticker('SPY')

ticker.history(start='2025-11-15', end='2025-11-23')
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2025-11-17 00:00:00-05:00  669.700012  673.710022  662.169983  665.669983
# 2025-11-18 00:00:00-05:00  662.099976  665.119995  655.859985  660.080017
# 2025-11-19 00:00:00-05:00  660.780029  667.340027  658.750000  662.630005
# 2025-11-20 00:00:00-05:00  672.909973  675.559998  651.890015  652.530029
# 2025-11-21 00:00:00-05:00  655.049988  664.549988  650.849976  659.030029
#
#                               Volume  Dividends  Stock Splits  Capital Gains
# Date
# 2025-11-17 00:00:00-05:00   90456100        0.0           0.0            0.0
# 2025-11-18 00:00:00-05:00  114467500        0.0           0.0            0.0
# 2025-11-19 00:00:00-05:00   94703000        0.0           0.0            0.0
# 2025-11-20 00:00:00-05:00  165293500        0.0           0.0            0.0
# 2025-11-21 00:00:00-05:00  123956200        0.0           0.0            0.0

# %%
# yfinance 버전 확인
import yfinance as yf
# 최신 버전으로 업데이트
# pip install --upgrade yfinance

# 간단한 테스트
import yfinance as yf
spy = yf.Ticker("SPY")
info = spy.info  # 메타데이터라도 가져와지는지 확인
print(info.get('shortName', 'N/A'))
# Out:
# yfinance 버전: 0.2.49
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[27], line 11
#       9 import yfinance as yf
#      10 spy = yf.Ticker("SPY")
# ---> 11 info = spy.info  # 메타데이터라도 가져와지는지 확인
#      12 print(info.get('shortName', 'N/A'))
#
# File ~/opt/anaconda3/envs/insight-invest/lib/python3.10/site-packages/yfinance/ticker.py:159, in info(self)
#     157 @property
#     158 def shares(self) -> _pd.DataFrame:
# --> 159     return self.get_shares()
#
# File ~/opt/anaconda3/envs/insight-invest/lib/python3.10/site-packages/yfinance/base.py:229, in get_info(self, proxy)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/opt/anaconda3/envs/insight-invest/lib/python3.10/site-packages/yfinance/scrapers/quote.py:508, in info(self)
#     505     self._already_fetched = False
# ...
